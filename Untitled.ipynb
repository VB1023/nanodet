# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import nanodet

# %%
# Try to import the NanoDet library
try:
    import nanodet
    print("NanoDet is successfully installed.")
    
    # Check the version if available
    print("NanoDet version:", nanodet.__version__)
except ImportError:
    print("NanoDet is not installed.")
# Out:
# NanoDet is successfully installed.
# NanoDet version: 1.0.0

# %%
# !python tools/train.py config/nanodet-plus-m_416-yolo.yml
# Out:
# [NanoDet][01-08 09:50:36]INFO:Setting up data...
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [NanoDet][01-08 09:50:36]INFO:Creating model...
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA RTX A2000') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# ...

# %%
# !python tools/train.py
# Out:
# usage: train.py [-h] [--local_rank LOCAL_RANK] [--seed SEED] config
# train.py: error: the following arguments are required: config

# %%
# !ls
# Out:
# build		   docs				       README.md
# config		   LICENSE			       requirements.txt
# demo		   logs.txt			       setup.py
# demo_android_ncnn  nanodet			       tests
# demo_libtorch	   nanodet.egg-info		       tools
# demo_mnn	   nanodet-plus-m_416_checkpoint.ckpt  Untitled1.ipynb
# demo_ncnn	   OBJECT.v8-5.coco-mmdetection        Untitled.ipynb
# demo_openvino	   Output			       workspace
# dist		   path

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nanodet
from nanodet import NanoDet
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import seaborn as sns
#       5 import nanodet
# ----> 6 from nanodet import NanoDet
#
# ImportError: cannot import name 'NanoDet' from 'nanodet' (/home/parul/Desktop/VInit/nanodet/nanodet/__init__.py)

# %%
# !from nanodet.model.arch.nanodet_plus import NanoDetPlus
print(NanoDetPlus.__init__.__code__.co_varnames)
# Out:
# /bin/bash: line 1: from: command not found
# ('self', 'backbone', 'fpn', 'aux_head', 'head', 'detach_epoch')

# %%
# !python tools/train.py config/nanodet-plus-m_416-yolo.yml
# Out:
# [NanoDet][01-09 14:18:41]INFO:Setting up data...
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [NanoDet][01-09 14:18:41]INFO:Creating model...
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA RTX A2000') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# ...

# %%
# !python demo/demo.py image --config config/nanodet-plus-m_416-yolo.yml --model workspace/nanodet-plus-m_416/model_best/model_best.ckpt --path OBJECT.v8-5.coco-mmdetection/train/IMG-20241204-WA0085_jpg.rf.9666815e241f95864860cd7110996a52.jpg
# Out:
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet-Plus Head.
# ...
